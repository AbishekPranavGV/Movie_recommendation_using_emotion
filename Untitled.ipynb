# %%
import pandas as pd
movie_data = pd.read_csv('Moviesdata.csv',encoding = 'ISO-8859-1')

# %%
movie_data.head(10)
# Out:
#    IMDBid  IMDBlink                                          Title  \
# 0     NaN       NaN                       The Shawshank Redemption
# 1     NaN       NaN                                  The Godfather
# 2     NaN       NaN                                The Dark Knight
# 3     NaN       NaN                         The Godfather: Part II
# 4     NaN       NaN                                   12 Angry Men
# 5     NaN       NaN  The Lord of the Rings: The Return of the King
# 6     NaN       NaN                                   Pulp Fiction
# 7     NaN       NaN                               Schindler's List
# 8     NaN       NaN                                      Inception
# 9     NaN       NaN                                     Fight Club
#
#                        Genre  IMDB_Rating  \
# 0                      Drama          9.3
# 1               Crime, Drama          9.2
# 2       Action, Crime, Drama          9.0
# 3               Crime, Drama          9.0
# ...

# %%
movie_data['Genre'].str.split('|', expand = True)
# Out:
#                             0
# 0                       Drama
# 1                Crime, Drama
# 2        Action, Crime, Drama
# 3                Crime, Drama
# 4                Crime, Drama
# ..                        ...
# 995    Comedy, Drama, Romance
# 996            Drama, Western
# 997       Drama, Romance, War
# 998                Drama, War
# 999  Crime, Mystery, Thriller
#
# [1000 rows x 1 columns]
